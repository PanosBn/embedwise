# %%
import datasets
from datasets import load_dataset

# %%
from embedwise.embedders import HuggingFaceEncoder, SentenceEncoder

# %%
# !pip install anywidget
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting anywidget
#   Downloading anywidget-0.7.1-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 KB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.2.0 in ./.venv/lib/python3.10/site-packages (from anywidget) (4.8.0)
# Requirement already satisfied: ipywidgets>=7.6.0 in ./.venv/lib/python3.10/site-packages (from anywidget) (8.1.1)
# Collecting psygnal>=0.8.1
#   Downloading psygnal-0.9.5-cp310-cp310-macosx_10_16_x86_64.whl (395 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.4/395.4 KB 5.6 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: comm>=0.1.3 in ./.venv/lib/python3.10/site-packages (from ipywidgets>=7.6.0->anywidget) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./.venv/lib/python3.10/site-packages (from ipywidgets>=7.6.0->anywidget) (4.0.9)
# Requirement already satisfied: ipython>=6.1.0 in ./.venv/lib/python3.10/site-packages (from ipywidgets>=7.6.0->anywidget) (8.18.1)
# Requirement already satisfied: traitlets>=4.3.1 in ./.venv/lib/python3.10/site-packages (from ipywidgets>=7.6.0->anywidget) (5.14.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./.venv/lib/python3.10/site-packages (from ipywidgets>=7.6.0->anywidget) (3.0.9)
# Requirement already satisfied: mypy-extensions in ./.venv/lib/python3.10/site-packages (from psygnal>=0.8.1->anywidget) (1.0.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (3.0.41)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (0.6.3)
# Requirement already satisfied: exceptiongroup in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (4.9.0)
# Requirement already satisfied: decorator in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (5.1.1)
# Requirement already satisfied: matplotlib-inline in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (0.1.6)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (2.17.2)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (0.19.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (0.7.0)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (0.2.12)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (2.4.1)
# Requirement already satisfied: six>=1.12.0 in ./.venv/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (1.16.0)
# Installing collected packages: psygnal, anywidget
# Successfully installed anywidget-0.7.1 psygnal-0.9.5
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/Users/panos/repos/embedwise/.venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install vega
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting vega
#   Downloading vega-4.0.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 7.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: jupyter<2.0.0,>=1.0.0 in ./.venv/lib/python3.10/site-packages (from vega) (1.0.0)
# Collecting ipytablewidgets<0.4.0,>=0.3.0
#   Downloading ipytablewidgets-0.3.1-py2.py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.2/190.2 KB 4.4 MB/s eta 0:00:0031m11.3 MB/s eta 0:00:01
# Collecting pandas<2.0.0,>=1.5.0
#   Downloading pandas-1.5.3-cp310-cp310-macosx_10_9_x86_64.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 6.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: traitlets>=4.3.0 in ./.venv/lib/python3.10/site-packages (from ipytablewidgets<0.4.0,>=0.3.0->vega) (5.14.0)
# Collecting lz4
#   Downloading lz4-4.3.2-cp310-cp310-macosx_10_9_x86_64.whl (254 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.2/254.2 KB 4.7 MB/s eta 0:00:009.7 MB/s eta 0:00:01
# Requirement already satisfied: numpy<2.0.0,>=1.10.4 in ./.venv/lib/python3.10/site-packages (from ipytablewidgets<0.4.0,>=0.3.0->vega) (1.26.2)
# Requirement already satisfied: ipywidgets<9,>=7.5.0 in ./.venv/lib/python3.10/site-packages (from ipytablewidgets<0.4.0,>=0.3.0->vega) (8.1.1)
# Collecting traittypes>=0.0.6
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: qtconsole in ./.venv/lib/python3.10/site-packages (from jupyter<2.0.0,>=1.0.0->vega) (5.5.1)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.10/site-packages (from jupyter<2.0.0,>=1.0.0->vega) (6.27.1)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.10/site-packages (from jupyter<2.0.0,>=1.0.0->vega) (7.11.0)
# Requirement already satisfied: notebook in ./.venv/lib/python3.10/site-packages (from jupyter<2.0.0,>=1.0.0->vega) (7.0.6)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.10/site-packages (from jupyter<2.0.0,>=1.0.0->vega) (6.6.3)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas<2.0.0,>=1.5.0->vega) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./.venv/lib/python3.10/site-packages (from pandas<2.0.0,>=1.5.0->vega) (2.8.2)
# Requirement already satisfied: ipython>=6.1.0 in ./.venv/lib/python3.10/site-packages (from ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (8.18.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./.venv/lib/python3.10/site-packages (from ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (4.0.9)
# Requirement already satisfied: comm>=0.1.3 in ./.venv/lib/python3.10/site-packages (from ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./.venv/lib/python3.10/site-packages (from ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (3.0.9)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.5.0->vega) (1.16.0)
# Requirement already satisfied: packaging in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (23.2)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (1.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (0.1.6)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (1.5.8)
# Requirement already satisfied: appnope in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (0.1.3)
# Requirement already satisfied: pyzmq>=20 in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (6.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (8.6.0)
# Requirement already satisfied: psutil in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (5.9.6)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (5.5.0)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in ./.venv/lib/python3.10/site-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->vega) (3.0.41)
# Requirement already satisfied: pygments in ./.venv/lib/python3.10/site-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->vega) (2.17.2)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (0.7.1)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (3.0.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (1.5.0)
# Requirement already satisfied: markupsafe>=2.0 in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (2.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (0.9.0)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (4.12.2)
# Requirement already satisfied: jinja2>=3.0 in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (3.1.2)
# Requirement already satisfied: bleach!=5.0.0 in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (6.1.0)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (0.3.0)
# Requirement already satisfied: tinycss2 in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (1.2.1)
# Requirement already satisfied: nbformat>=5.7 in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (5.9.2)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./.venv/lib/python3.10/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->vega) (0.2.3)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./.venv/lib/python3.10/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->vega) (2.25.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in ./.venv/lib/python3.10/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->vega) (4.0.9)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.10/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->vega) (2.11.1)
# Requirement already satisfied: qtpy>=2.4.0 in ./.venv/lib/python3.10/site-packages (from qtconsole->jupyter<2.0.0,>=1.0.0->vega) (2.4.1)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->vega) (0.5.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (0.19.1)
# Requirement already satisfied: exceptiongroup in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (4.9.0)
# Requirement already satisfied: decorator in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (5.1.1)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter<2.0.0,>=1.0.0->vega) (4.0.0)
# Requirement already satisfied: argon2-cffi in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (23.1.0)
# Requirement already satisfied: anyio>=3.1.0 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (4.1.0)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (0.18.0)
# Requirement already satisfied: jupyter-server-terminals in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (0.4.4)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (0.9.0)
# Requirement already satisfied: prometheus-client in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (0.19.0)
# Requirement already satisfied: websocket-client in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (1.6.4)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (1.8.2)
# Requirement already satisfied: overrides in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (7.4.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter<2.0.0,>=1.0.0->vega) (2.0.4)
# Requirement already satisfied: tomli in ./.venv/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter<2.0.0,>=1.0.0->vega) (2.0.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter<2.0.0,>=1.0.0->vega) (2.2.1)
# Requirement already satisfied: jsonschema>=4.18.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (4.20.0)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (2.13.1)
# Requirement already satisfied: requests>=2.31 in ./.venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (2.31.0)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (0.9.14)
# Requirement already satisfied: fastjsonschema in ./.venv/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->vega) (2.19.0)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.10/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter<2.0.0,>=1.0.0->vega) (0.2.12)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter<2.0.0,>=1.0.0->vega) (2.5)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (3.6)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./.venv/lib/python3.10/site-packages (from async-lru>=1.0.0->jupyterlab<5,>=4.0.2->notebook->jupyter<2.0.0,>=1.0.0->vega) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (0.8.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (0.13.1)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (23.1.0)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (0.1.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in ./.venv/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (6.0.1)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (2023.11.17)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (1.26.18)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.10/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (21.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (2.4.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (2.0.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (2.4)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (1.13)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (1.5.1)
# Requirement already satisfied: cffi>=1.0.1 in ./.venv/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (1.16.0)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->vega) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.10/site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->vega) (2.8.19.14)
# Installing collected packages: traittypes, lz4, pandas, ipytablewidgets, vega
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.3
#     Uninstalling pandas-2.1.3:
#       Successfully uninstalled pandas-2.1.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# embedwise 0.1.0 requires pandas<3.0.0,>=2.1.2, but you have pandas 1.5.3 which is incompatible.
# Successfully installed ipytablewidgets-0.3.1 lz4-4.3.2 pandas-1.5.3 traittypes-0.2.1 vega-4.0.0
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/Users/panos/repos/embedwise/.venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install vega_datasets
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting vega_datasets
#   Using cached vega_datasets-0.9.0-py3-none-any.whl (210 kB)
# Requirement already satisfied: pandas in ./.venv/lib/python3.10/site-packages (from vega_datasets) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./.venv/lib/python3.10/site-packages (from pandas->vega_datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas->vega_datasets) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in ./.venv/lib/python3.10/site-packages (from pandas->vega_datasets) (1.26.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->vega_datasets) (1.16.0)
# Installing collected packages: vega_datasets
# Successfully installed vega_datasets-0.9.0
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/Users/panos/repos/embedwise/.venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install altair

# %%
# !pip install altair_viewer
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting altair_viewer
#   Downloading altair_viewer-0.4.0-py3-none-any.whl (844 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 844.5/844.5 KB 8.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting altair-data-server>=0.4.0
#   Using cached altair_data_server-0.4.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: altair in ./.venv/lib/python3.10/site-packages (from altair_viewer) (5.2.0)
# Collecting portpicker
#   Downloading portpicker-1.6.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: tornado in ./.venv/lib/python3.10/site-packages (from altair-data-server>=0.4.0->altair_viewer) (6.4)
# Requirement already satisfied: toolz in ./.venv/lib/python3.10/site-packages (from altair->altair_viewer) (0.12.0)
# Requirement already satisfied: typing-extensions>=4.0.1 in ./.venv/lib/python3.10/site-packages (from altair->altair_viewer) (4.8.0)
# Requirement already satisfied: pandas>=0.25 in ./.venv/lib/python3.10/site-packages (from altair->altair_viewer) (1.5.3)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.10/site-packages (from altair->altair_viewer) (3.1.2)
# Requirement already satisfied: numpy in ./.venv/lib/python3.10/site-packages (from altair->altair_viewer) (1.26.2)
# Requirement already satisfied: jsonschema>=3.0 in ./.venv/lib/python3.10/site-packages (from altair->altair_viewer) (4.20.0)
# Requirement already satisfied: packaging in ./.venv/lib/python3.10/site-packages (from altair->altair_viewer) (23.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.10/site-packages (from jsonschema>=3.0->altair->altair_viewer) (2023.11.1)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.10/site-packages (from jsonschema>=3.0->altair->altair_viewer) (23.1.0)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.10/site-packages (from jsonschema>=3.0->altair->altair_viewer) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.10/site-packages (from jsonschema>=3.0->altair->altair_viewer) (0.13.1)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas>=0.25->altair->altair_viewer) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./.venv/lib/python3.10/site-packages (from pandas>=0.25->altair->altair_viewer) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from jinja2->altair->altair_viewer) (2.1.3)
# Requirement already satisfied: psutil in ./.venv/lib/python3.10/site-packages (from portpicker->altair-data-server>=0.4.0->altair_viewer) (5.9.6)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=0.25->altair->altair_viewer) (1.16.0)
# Installing collected packages: portpicker, altair-data-server, altair_viewer
# Successfully installed altair-data-server-0.4.1 altair_viewer-0.4.0 portpicker-1.6.0
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/Users/panos/repos/embedwise/.venv/bin/python -m pip install --upgrade pip' command.

# %%
encoder = HuggingFaceEncoder("bert-base-uncased")

# %%
sent_encoder = SentenceEncoder()

# %%
dataset = load_dataset("ag_news")
# Out:
# Downloading builder script:   0%|          | 0.00/4.06k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.65k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/7.95k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.0M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/751k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/120000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/7600 [00:00<?, ? examples/s]

# %%
texts = dataset['train']['text'][600:1000]
labels = dataset['train']['label'][600:1000]

# %%
# Encode the texts
embeddings = sent_encoder.get_embedding(texts)

# Reduce dimensions
reduced_embeddings = sent_encoder.reduce_dimensions(embeddings, method='tsne')
# Out:
# Batches:   0%|          | 0/13 [00:00<?, ?it/s]

# %%
def map_label(num):
    labels = {0: "World", 1: "Sports", 2: "Business", 3: "Sci/Tech"}
    return labels.get(num, "Unknown")  # Default to "Unknown" if the number is not in the dictionary

text_labels = [map_label(num) for num in labels]

# %%
import pandas as pd

# Create a DataFrame for the embeddings
df = pd.DataFrame(reduced_embeddings, columns=['x', 'y'])
df['label'] = text_labels  # Add the labels
df['text'] = texts

# %%
import altair as alt


# Create a scatter plot
alt.Chart(df).mark_circle(size=60).encode(
    x='x',
    y='y',
    color='label:N',
    tooltip=['label:N', 'text']
).interactive()
# Out:
# alt.Chart(...)

# %%
# Encode the texts
embeddings = encoder.get_embedding(texts)

# Reduce dimensions
reduced_embeddings = encoder.reduce_dimensions(embeddings, method='tsne')

# %%
df_hf = pd.DataFrame(reduced_embeddings, columns=['x', 'y'])
df_hf['label'] = text_labels  # Add the labels
df_hf['text'] = texts

# %%
alt.Chart(df_hf).mark_circle(size=60).encode(
    x='x',
    y='y',
    color='label:N',
    tooltip=['label:N', 'text']
).interactive()
# Out:
# alt.Chart(...)
